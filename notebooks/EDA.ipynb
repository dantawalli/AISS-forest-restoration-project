# %% [markdown]
# ### Loading GFW Dataset

# %%
import pandas as pd
RAW_PATH = "../data/raw/global_forest_watch_raw_data.xlsx"
global_forest_watch_excel_file = pd.ExcelFile(RAW_PATH)

# %% [markdown]
# ### Exploaring Country tree cover loss

# %%
country_tree_cover_loss_sheet = global_forest_watch_excel_file.parse("Country tree cover loss")
print(country_tree_cover_loss_sheet.head())
print(country_tree_cover_loss_sheet.info())
# Out:
#        country  threshold   area_ha  extent_2000_ha  extent_2010_ha  \
# 0  Afghanistan          0  64383655        64383655        64383655
# 1  Afghanistan         10  64383655          432070          126231
# 2  Afghanistan         15  64383655          302629          106852
# 3  Afghanistan         20  64383655          284330          105718
# 4  Afghanistan         25  64383655          254843           72384
#
#    gain_2000-2012_ha  tc_loss_ha_2001  tc_loss_ha_2002  tc_loss_ha_2003  \
# 0              10738              103              214              267
# 1              10738               92              190              254
# 2              10738               91              186              248
# 3              10738               89              181              245
# 4              10738               89              180              244
#
#    tc_loss_ha_2004  ...  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0              226  ...                0                0                0
# 1              207  ...                0                0                0
# 2              205  ...                0                0                0
# 3              203  ...                0                0                0
# 4              202  ...                0                0                0
#
#    tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 0               31               25               46               47
# 1               28               19               40               37
# 2               28               19               39               32
# 3               28               18               39               32
# 4               27               18               38               27
#
#    tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# 0               16              133              223
# 1                9               32               32
# 2                7               23               17
# 3                7               22               16
# 4                6               21               14
#
# [5 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            1328 non-null   object
#  1   threshold          1328 non-null   int64
#  2   area_ha            1328 non-null   int64
#  3   extent_2000_ha     1328 non-null   int64
#  4   extent_2010_ha     1328 non-null   int64
#  5   gain_2000-2012_ha  1328 non-null   int64
#  6   tc_loss_ha_2001    1328 non-null   int64
#  7   tc_loss_ha_2002    1328 non-null   int64
#  8   tc_loss_ha_2003    1328 non-null   int64
#  9   tc_loss_ha_2004    1328 non-null   int64
#  10  tc_loss_ha_2005    1328 non-null   int64
#  11  tc_loss_ha_2006    1328 non-null   int64
#  12  tc_loss_ha_2007    1328 non-null   int64
#  13  tc_loss_ha_2008    1328 non-null   int64
#  14  tc_loss_ha_2009    1328 non-null   int64
#  15  tc_loss_ha_2010    1328 non-null   int64
#  16  tc_loss_ha_2011    1328 non-null   int64
#  17  tc_loss_ha_2012    1328 non-null   int64
#  18  tc_loss_ha_2013    1328 non-null   int64
#  19  tc_loss_ha_2014    1328 non-null   int64
#  20  tc_loss_ha_2015    1328 non-null   int64
#  21  tc_loss_ha_2016    1328 non-null   int64
#  22  tc_loss_ha_2017    1328 non-null   int64
#  23  tc_loss_ha_2018    1328 non-null   int64
#  24  tc_loss_ha_2019    1328 non-null   int64
#  25  tc_loss_ha_2020    1328 non-null   int64
#  26  tc_loss_ha_2021    1328 non-null   int64
#  27  tc_loss_ha_2022    1328 non-null   int64
#  28  tc_loss_ha_2023    1328 non-null   int64
#  29  tc_loss_ha_2024    1328 non-null   int64
# dtypes: int64(29), object(1)
# memory usage: 311.4+ KB
# None
