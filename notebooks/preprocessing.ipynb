# %% [markdown]
# # Data Download and Documentation
# ## Global Forest Watch Data - 2001-2024
#
# **Purpose:** Data Wrangling
# 1. Preprocessing: Convert data from Excel sheets to csv files because it is easier to integrate with Data Science libraries like Pandas, NumPy, scikit-learn, and TensorFlow
# 2. Check missing values
# 3. Check data formats
# 4. Check the data shape
#
# **Data Source:** Global Forest Watch (globalforestwatch.org)
#
# **Date:** 2025-10-22

# %%
# Import libraries
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from scipy.stats import zscore

# Configure visual style
sns.set(style="whitegrid", palette="Set2")
plt.rcParams["figure.figsize"] = (12, 6)


print(f"✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
# Specify your Excel file
excel_file = Path('../data/raw/global_forest_watch_raw_data.xlsx')
output_dir = Path('../data/processed/')

# Read all sheets
excel_data = pd.ExcelFile(excel_file)

# Convert each sheet
for sheet_name in excel_data.sheet_names:
    # Read sheet
    df = pd.read_excel(excel_file, sheet_name=sheet_name)

    # Save as CSV
    csv_filename = f"{excel_file.stem}_{sheet_name}.csv"
    csv_path = output_dir / csv_filename
    df.to_csv(csv_path, index=False)

    print(f"✓ Converted: {sheet_name} -> {csv_filename}")
# Out:
# ✓ Converted: Read_Me -> global_forest_watch_raw_data_Read_Me.csv
# ✓ Converted: Country tree cover loss -> global_forest_watch_raw_data_Country tree cover loss.csv
# ✓ Converted: Country primary loss -> global_forest_watch_raw_data_Country primary loss.csv
# ✓ Converted: Country drivers -> global_forest_watch_raw_data_Country drivers.csv
# ✓ Converted: Country carbon data -> global_forest_watch_raw_data_Country carbon data.csv
# ✓ Converted: Subnational 1 tree cover loss -> global_forest_watch_raw_data_Subnational 1 tree cover loss.csv
# ✓ Converted: Subnational 1 primary loss -> global_forest_watch_raw_data_Subnational 1 primary loss.csv
# ✓ Converted: Subnational 1 drivers -> global_forest_watch_raw_data_Subnational 1 drivers.csv
# ✓ Converted: Subnational 1 carbon data -> global_forest_watch_raw_data_Subnational 1 carbon data.csv

# %% [markdown]
# ## 1. Data Overview
#
# ### Available Datasets:
#
# **Country Level:**
# 1. **Country Tree Cover Loss** - Hectares of tree cover loss (2001-2024)
# 2. **Country Primary Loss** - Humid tropical primary forest loss (2002-2024)
# 3. **Country Carbon Data** - Biomass stocks, emissions, removals, net flux
# 4. **Country Drivers** - Tree cover loss by dominant driver (2001-2024)
#
# **Subnational Level (State/Province):**
# 1. **Subnational Tree Cover Loss** - First level administrative data
# 2. **Subnational Primary Loss** - State/province level primary forest loss
# 3. **Subnational Carbon Data** - Regional carbon emissions and removals
# 4. **Subnational Drivers** - Regional drivers of deforestation

# %% [markdown]
# ## 3. Load and Inspect Each Dataset
#
# ### 3.1 Country Tree Cover Loss

# %%
# Load country tree cover loss data
# NOTE: Update the filename to match your actual file
country_loss_file = "../data/raw/global_forest_watch_country_tree_cover_loss.csv"

df_country_loss = pd.read_csv(country_loss_file)
print("✓ Country Tree Cover Loss Data Loaded")
print(f"Shape: {df_country_loss.shape}")
print(f"\nColumns: {list(df_country_loss.columns)}")

print(f"\nFirst few rows:")
display(df_country_loss.head())

print(f"\nLast few rows:")
display(df_country_loss.tail())
    
print(f"\nData Types:")
print(df_country_loss.dtypes)
    
print(f"\nMissing Values:")
print(df_country_loss.isnull().sum())
# Out:
# ✓ Country Tree Cover Loss Data Loaded
# Shape: (1328, 30)
#
# Columns: ['country', 'threshold', 'area_ha', 'extent_2000_ha', 'extent_2010_ha', 'gain_2000-2012_ha', 'tc_loss_ha_2001', 'tc_loss_ha_2002', 'tc_loss_ha_2003', 'tc_loss_ha_2004', 'tc_loss_ha_2005', 'tc_loss_ha_2006', 'tc_loss_ha_2007', 'tc_loss_ha_2008', 'tc_loss_ha_2009', 'tc_loss_ha_2010', 'tc_loss_ha_2011', 'tc_loss_ha_2012', 'tc_loss_ha_2013', 'tc_loss_ha_2014', 'tc_loss_ha_2015', 'tc_loss_ha_2016', 'tc_loss_ha_2017', 'tc_loss_ha_2018', 'tc_loss_ha_2019', 'tc_loss_ha_2020', 'tc_loss_ha_2021', 'tc_loss_ha_2022', 'tc_loss_ha_2023', 'tc_loss_ha_2024']
#
# First few rows:
#        country  threshold   area_ha  extent_2000_ha  extent_2010_ha  \
# 0  Afghanistan          0  64383655        64383655        64383655
# 1  Afghanistan         10  64383655          432070          126231
# 2  Afghanistan         15  64383655          302629          106852
# 3  Afghanistan         20  64383655          284330          105718
# 4  Afghanistan         25  64383655          254843           72384
#
#    gain_2000-2012_ha  tc_loss_ha_2001  tc_loss_ha_2002  tc_loss_ha_2003  \
# 0              10738              103              214              267
# 1              10738               92              190              254
# 2              10738               91              186              248
# 3              10738               89              181              245
# 4              10738               89              180              244
#
#    tc_loss_ha_2004  ...  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0              226  ...                0                0                0
# 1              207  ...                0                0                0
# 2              205  ...                0                0                0
# 3              203  ...                0                0                0
# 4              202  ...                0                0                0
#
#    tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 0               31               25               46               47
# 1               28               19               40               37
# 2               28               19               39               32
# 3               28               18               39               32
# 4               27               18               38               27
#
#    tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# 0               16              133              223
# 1                9               32               32
# 2                7               23               17
# 3                7               22               16
# 4                6               21               14
#
# [5 rows x 30 columns]
# Last few rows:
#      country  threshold  area_ha  extent_2000_ha  extent_2010_ha  \
# 1323   Åland         20   150613          109897          108508
# 1324   Åland         25   150613          108748          104703
# 1325   Åland         30   150613          107739          103087
# 1326   Åland         50   150613           87773           85300
# 1327   Åland         75   150613           60890           60461
#
#       gain_2000-2012_ha  tc_loss_ha_2001  tc_loss_ha_2002  tc_loss_ha_2003  \
# 1323               2583              398              278              221
# 1324               2583              397              278              221
# 1325               2583              397              277              221
# 1326               2583              389              274              216
# 1327               2583              358              256              205
#
#       tc_loss_ha_2004  ...  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 1323              736  ...              568              675              737
# 1324              736  ...              567              674              736
# 1325              736  ...              567              672              735
# 1326              728  ...              547              641              704
# 1327              694  ...              484              551              606
#
#       tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 1323              621             2364              675             1357
# 1324              620             2363              675             1356
# 1325              620             2361              674             1355
# 1326              604             2331              663             1327
# 1327              538             2180              608             1193
#
#       tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# 1323             1173             1098              955
# 1324             1170             1096              954
# 1325             1167             1093              951
# 1326             1098             1045              899
# 1327              926              910              756
#
# [5 rows x 30 columns]
# Data Types:
# country              object
# threshold             int64
# area_ha               int64
# extent_2000_ha        int64
# extent_2010_ha        int64
# gain_2000-2012_ha     int64
# tc_loss_ha_2001       int64
# tc_loss_ha_2002       int64
# tc_loss_ha_2003       int64
# tc_loss_ha_2004       int64
# tc_loss_ha_2005       int64
# tc_loss_ha_2006       int64
# tc_loss_ha_2007       int64
# tc_loss_ha_2008       int64
# tc_loss_ha_2009       int64
# tc_loss_ha_2010       int64
# tc_loss_ha_2011       int64
# tc_loss_ha_2012       int64
# tc_loss_ha_2013       int64
# tc_loss_ha_2014       int64
# tc_loss_ha_2015       int64
# tc_loss_ha_2016       int64
# tc_loss_ha_2017       int64
# tc_loss_ha_2018       int64
# tc_loss_ha_2019       int64
# tc_loss_ha_2020       int64
# tc_loss_ha_2021       int64
# tc_loss_ha_2022       int64
# tc_loss_ha_2023       int64
# tc_loss_ha_2024       int64
# dtype: object
#
# Missing Values:
# country              0
# threshold            0
# area_ha              0
# extent_2000_ha       0
# extent_2010_ha       0
# gain_2000-2012_ha    0
# tc_loss_ha_2001      0
# tc_loss_ha_2002      0
# tc_loss_ha_2003      0
# tc_loss_ha_2004      0
# tc_loss_ha_2005      0
# tc_loss_ha_2006      0
# tc_loss_ha_2007      0
# tc_loss_ha_2008      0
# tc_loss_ha_2009      0
# tc_loss_ha_2010      0
# tc_loss_ha_2011      0
# tc_loss_ha_2012      0
# tc_loss_ha_2013      0
# tc_loss_ha_2014      0
# tc_loss_ha_2015      0
# tc_loss_ha_2016      0
# tc_loss_ha_2017      0
# tc_loss_ha_2018      0
# tc_loss_ha_2019      0
# tc_loss_ha_2020      0
# tc_loss_ha_2021      0
# tc_loss_ha_2022      0
# tc_loss_ha_2023      0
# tc_loss_ha_2024      0
# dtype: int64

# %% [markdown]
# ### 3.2 Country Primary Loss

# %%
# Load country primary loss data
primary_loss_file = "../data/raw/global_forest_watch_country_primary_loss.csv"
df_primary_loss = pd.read_csv(primary_loss_file)
print("✓ Country Primary Loss Data Loaded")
print(f"Shape: {df_primary_loss.shape}")
print(f"\nColumns: {list(df_primary_loss.columns)}")


print(f"\nFirst few rows:")
display(df_primary_loss.head())

print(f"\nLast few rows:")
display(df_primary_loss.tail())

print(f"\nData Types:")
print(df_primary_loss.dtypes)

print(f"\nMissing Values:")
print(df_primary_loss.isnull().sum())
# Out:
# ✓ Country Primary Loss Data Loaded
# Shape: (76, 26)
#
# Columns: ['country', 'threshold', 'area__ha', 'tc_loss_ha_2002', 'tc_loss_ha_2003', 'tc_loss_ha_2004', 'tc_loss_ha_2005', 'tc_loss_ha_2006', 'tc_loss_ha_2007', 'tc_loss_ha_2008', 'tc_loss_ha_2009', 'tc_loss_ha_2010', 'tc_loss_ha_2011', 'tc_loss_ha_2012', 'tc_loss_ha_2013', 'tc_loss_ha_2014', 'tc_loss_ha_2015', 'tc_loss_ha_2016', 'tc_loss_ha_2017', 'tc_loss_ha_2018', 'tc_loss_ha_2019', 'tc_loss_ha_2020', 'tc_loss_ha_2021', 'tc_loss_ha_2022', 'tc_loss_ha_2023', 'tc_loss_ha_2024']
#
# First few rows:
#       country  threshold  area__ha  tc_loss_ha_2002  tc_loss_ha_2003  \
# 0      Angola         30   2458061             3499             2963
# 1   Argentina         30   4418724             9318            14459
# 2   Australia         30     13977                0                0
# 3  Bangladesh         30    101114              619              266
# 4      Belize         30   1165487             5570             2993
#
#    tc_loss_ha_2004  tc_loss_ha_2005  tc_loss_ha_2006  tc_loss_ha_2007  \
# 0             2354             3110             1400             8060
# 1            28090            31429            24095            18687
# 2                0                0               25                0
# 3              347              306              677              369
# 4             2108             3206             1899             4140
#
#    tc_loss_ha_2008  ...  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0             2699  ...             8998            12040            11166
# 1            47067  ...            10547            15247            17202
# 2                0  ...                5                0                0
# 3              240  ...              205              345              414
# 4             3632  ...             6606            11511             6616
#
#    tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 0            13507             9995             8895            24326
# 1             9496             8983            20847            11921
# 2                0                5                0                0
# 3              358              387              459              308
# 4             4781             8772            16087             4560
#
#    tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# 0            15576            17627            13660
# 1            21388            11473            12103
# 2                0                0                0
# 3              307              743              467
# 4             4033            11667            21137
#
# [5 rows x 26 columns]
# Last few rows:
#                  country  threshold  area__ha  tc_loss_ha_2002  \
# 71             Venezuela         30  38654064            11320
# 72               Vietnam         30   6792860            11028
# 73  Virgin Islands, U.S.         30      2762                0
# 74                Zambia         30    331125               62
# 75              Zimbabwe         30      7612               14
#
#     tc_loss_ha_2003  tc_loss_ha_2004  tc_loss_ha_2005  tc_loss_ha_2006  \
# 71            20761            15891            15561            14243
# 72             9521            21113            27779            20141
# 73                6                0                1                1
# 74              133              431              242              277
# 75                8               20               27               25
#
#     tc_loss_ha_2007  tc_loss_ha_2008  ...  tc_loss_ha_2015  tc_loss_ha_2016  \
# 71            26102            19852  ...            15534            84699
# 72            22289            34412  ...            38580            68841
# 73                1                0  ...                0                0
# 74              538              305  ...             2336             2860
# 75               16                8  ...               62               50
#
#     tc_loss_ha_2017  tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  \
# 71            43748            30125            58767            53669
# 72            45060            33410            30898            32629
# 73                0                0                0                0
# 74             3360             2424             2555             2165
# 75              275               27               50               37
#
#     tc_loss_ha_2021  tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# 71            22680            19802            27488            74428
# 72            29028            21676            16455            16924
# 73                0                0                0                0
# 74             2911             2422             2675             3913
# 75               42               55               40               32
#
# [5 rows x 26 columns]
# Data Types:
# country            object
# threshold           int64
# area__ha            int64
# tc_loss_ha_2002     int64
# tc_loss_ha_2003     int64
# tc_loss_ha_2004     int64
# tc_loss_ha_2005     int64
# tc_loss_ha_2006     int64
# tc_loss_ha_2007     int64
# tc_loss_ha_2008     int64
# tc_loss_ha_2009     int64
# tc_loss_ha_2010     int64
# tc_loss_ha_2011     int64
# tc_loss_ha_2012     int64
# tc_loss_ha_2013     int64
# tc_loss_ha_2014     int64
# tc_loss_ha_2015     int64
# tc_loss_ha_2016     int64
# tc_loss_ha_2017     int64
# tc_loss_ha_2018     int64
# tc_loss_ha_2019     int64
# tc_loss_ha_2020     int64
# tc_loss_ha_2021     int64
# tc_loss_ha_2022     int64
# tc_loss_ha_2023     int64
# tc_loss_ha_2024     int64
# dtype: object
#
# Missing Values:
# country            0
# threshold          0
# area__ha           0
# tc_loss_ha_2002    0
# tc_loss_ha_2003    0
# tc_loss_ha_2004    0
# tc_loss_ha_2005    0
# tc_loss_ha_2006    0
# tc_loss_ha_2007    0
# tc_loss_ha_2008    0
# tc_loss_ha_2009    0
# tc_loss_ha_2010    0
# tc_loss_ha_2011    0
# tc_loss_ha_2012    0
# tc_loss_ha_2013    0
# tc_loss_ha_2014    0
# tc_loss_ha_2015    0
# tc_loss_ha_2016    0
# tc_loss_ha_2017    0
# tc_loss_ha_2018    0
# tc_loss_ha_2019    0
# tc_loss_ha_2020    0
# tc_loss_ha_2021    0
# tc_loss_ha_2022    0
# tc_loss_ha_2023    0
# tc_loss_ha_2024    0
# dtype: int64

# %% [markdown]
# ### 3.3 Country Carbon Data

# %%
# Load country carbon data
carbon_file = "../data/raw/global_forest_watch_country_carbon_data.csv"

df_carbon = pd.read_csv(carbon_file)
print("✓ Country Carbon Data Loaded")
print(f"Shape: {df_carbon.shape}")
print(f"\nColumns: {list(df_carbon.columns)}")

print(f"\nFirst few rows:")
display(df_carbon.head())

print(f"\nLast few rows:")
display(df_carbon.tail())

print(f"\nData Types:")
print(df_carbon.dtypes)

print(f"\nMissing Values:")
print(df_carbon.isnull().sum())
# Out:
# ✓ Country Carbon Data Loaded
# Shape: (498, 32)
#
# Columns: ['country', 'umd_tree_cover_density_2000__threshold', 'umd_tree_cover_extent_2000__ha', 'gfw_aboveground_carbon_stocks_2000__Mg_C', 'avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1', 'gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1', 'gfw_forest_carbon_gross_removals__Mg_CO2_yr-1', 'gfw_forest_carbon_net_flux__Mg_CO2e_yr-1', 'gfw_forest_carbon_gross_emissions_2001__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2002__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2003__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2004__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2005__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2006__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2007__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2008__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2009__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2010__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2011__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2012__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2013__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2014__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2015__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2016__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2017__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2018__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2019__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2020__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2021__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2022__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2023__Mg_CO2e', 'gfw_forest_carbon_gross_emissions_2024__Mg_CO2e']
#
# First few rows:
#        country  umd_tree_cover_density_2000__threshold  \
# 0  Afghanistan                                      30
# 1  Afghanistan                                      50
# 2  Afghanistan                                      75
# 3      Albania                                      30
# 4      Albania                                      50
#
#    umd_tree_cover_extent_2000__ha  gfw_aboveground_carbon_stocks_2000__Mg_C  \
# 0                          205771                                  12409398
# 1                          148417                                   9765465
# 2                           75480                                   5571655
# 3                          648459                                  40958831
# 4                          534671                                  37239867
#
#    avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1  \
# 0                                                123
# 1                                                134
# 2                                                150
# 3                                                238
# 4                                                263
#
#    gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1  \
# 0                                            15339
# 1                                            12657
# 2                                             6147
# 3                                           721806
# 4                                           682919
#
#    gfw_forest_carbon_gross_removals__Mg_CO2_yr-1  \
# 0                                         376800
# 1                                         275855
# 2                                         151074
# 3                                        5103589
# 4                                        4294627
#
#    gfw_forest_carbon_net_flux__Mg_CO2e_yr-1  \
# 0                                   -361461
# 1                                   -263199
# 2                                   -144926
# 3                                  -4381783
# 4                                  -3611709
#
#    gfw_forest_carbon_gross_emissions_2001__Mg_CO2e  \
# 0                                          27986.0
# 1                                          25603.0
# 2                                          15780.0
# 3                                        1417747.0
# 4                                        1358272.0
#
#    gfw_forest_carbon_gross_emissions_2002__Mg_CO2e  ...  \
# 0                                          41762.0  ...
# 1                                          32691.0  ...
# 2                                          15308.0  ...
# 3                                         348556.0  ...
# 4                                         338279.0  ...
#
#    gfw_forest_carbon_gross_emissions_2015__Mg_CO2e  \
# 0                                              0.0
# 1                                              0.0
# 2                                              0.0
# 3                                         120041.0
# 4                                         113553.0
#
#    gfw_forest_carbon_gross_emissions_2016__Mg_CO2e  \
# 0                                              0.0
# 1                                              0.0
# 2                                              0.0
# 3                                         334094.0
# 4                                         304691.0
#
#    gfw_forest_carbon_gross_emissions_2017__Mg_CO2e  \
# 0                                              0.0
# 1                                              0.0
# 2                                              0.0
# 3                                         448993.0
# 4                                         403366.0
#
#    gfw_forest_carbon_gross_emissions_2018__Mg_CO2e  \
# 0                                           4893.0
# 1                                           3920.0
# 2                                           1962.0
# 3                                         724335.0
# 4                                         669011.0
#
#    gfw_forest_carbon_gross_emissions_2019__Mg_CO2e  \
# 0                                           3708.0
# 1                                           3343.0
# 2                                           1743.0
# 3                                         429556.0
# 4                                         404887.0
#
#    gfw_forest_carbon_gross_emissions_2020__Mg_CO2e  \
# 0                                          11409.0
# 1                                          10321.0
# 2                                           6451.0
# 3                                         427420.0
# 4                                         391385.0
#
#    gfw_forest_carbon_gross_emissions_2021__Mg_CO2e  \
# 0                                           6772.0
# 1                                           6045.0
# 2                                           2477.0
# 3                                         506228.0
# 4                                         449937.0
#
#    gfw_forest_carbon_gross_emissions_2022__Mg_CO2e  \
# 0                                           1913.0
# 1                                           1664.0
# 2                                            668.0
# 3                                         649874.0
# 4                                         591504.0
#
#    gfw_forest_carbon_gross_emissions_2023__Mg_CO2e  \
# 0                                           3435.0
# 1                                           2530.0
# 2                                           1857.0
# 3                                         948758.0
# 4                                         895138.0
#
#    gfw_forest_carbon_gross_emissions_2024__Mg_CO2e
# 0                                           2636.0
# 1                                           2106.0
# 2                                           1512.0
# 3                                         308121.0
# 4                                         275104.0
#
# [5 rows x 32 columns]
# Last few rows:
#       country  umd_tree_cover_density_2000__threshold  \
# 493  Zimbabwe                                      50
# 494  Zimbabwe                                      75
# 495     Åland                                      30
# 496     Åland                                      50
# 497     Åland                                      75
#
#      umd_tree_cover_extent_2000__ha  gfw_aboveground_carbon_stocks_2000__Mg_C  \
# 493                          292639                                  26987292
# 494                           79815                                   9489605
# 495                          107739                                   3702622
# 496                           87773                                   3178873
# 497                           60890                                   2416128
#
#      avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1  \
# 493                                                455
# 494                                                637
# 495                                                 63
# 496                                                 68
# 497                                                 76
#
#      gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1  \
# 493                                          3463393
# 494                                          1755946
# 495                                           199822
# 496                                           196055
# 497                                           181482
#
#      gfw_forest_carbon_gross_removals__Mg_CO2_yr-1  \
# 493                                        2010161
# 494                                        1138565
# 495                                         548179
# 496                                         461029
# 497                                         325900
#
#      gfw_forest_carbon_net_flux__Mg_CO2e_yr-1  \
# 493                                   1453234
# 494                                    617383
# 495                                   -348357
# 496                                   -264974
# 497                                   -144418
#
#      gfw_forest_carbon_gross_emissions_2001__Mg_CO2e  \
# 493                                        2202552.0
# 494                                         846377.0
# 495                                          76145.0
# 496                                          75336.0
# 497                                          71162.0
#
#      gfw_forest_carbon_gross_emissions_2002__Mg_CO2e  ...  \
# 493                                        1852703.0  ...
# 494                                         547785.0  ...
# 495                                          55690.0  ...
# 496                                          55291.0  ...
# 497                                          52714.0  ...
#
#      gfw_forest_carbon_gross_emissions_2015__Mg_CO2e  \
# 493                                        5543212.0
# 494                                        3282965.0
# 495                                         146921.0
# 496                                         143102.0
# 497                                         129805.0
#
#      gfw_forest_carbon_gross_emissions_2016__Mg_CO2e  \
# 493                                        4287548.0
# 494                                        2294634.0
# 495                                         181156.0
# 496                                         174662.0
# 497                                         154716.0
#
#      gfw_forest_carbon_gross_emissions_2017__Mg_CO2e  \
# 493                                       11037857.0
# 494                                        5274064.0
# 495                                         204553.0
# 496                                         198103.0
# 497                                         175621.0
#
#      gfw_forest_carbon_gross_emissions_2018__Mg_CO2e  \
# 493                                        2313022.0
# 494                                        1197189.0
# 495                                         181186.0
# 496                                         177686.0
# 497                                         161701.0
#
#      gfw_forest_carbon_gross_emissions_2019__Mg_CO2e  \
# 493                                        4481712.0
# 494                                        1989239.0
# 495                                         720707.0
# 496                                         714011.0
# 497                                         676792.0
#
#      gfw_forest_carbon_gross_emissions_2020__Mg_CO2e  \
# 493                                        2463018.0
# 494                                        1311713.0
# 495                                         206427.0
# 496                                         204098.0
# 497                                         190477.0
#
#      gfw_forest_carbon_gross_emissions_2021__Mg_CO2e  \
# 493                                        2921155.0
# 494                                        1691041.0
# 495                                         422422.0
# 496                                         415748.0
# 497                                         381685.0
#
#      gfw_forest_carbon_gross_emissions_2022__Mg_CO2e  \
# 493                                        3646542.0
# 494                                        2068057.0
# 495                                         365660.0
# 496                                         348926.0
# 497                                         304561.0
#
#      gfw_forest_carbon_gross_emissions_2023__Mg_CO2e  \
# 493                                        2163212.0
# 494                                        1219051.0
# 495                                         354122.0
# 496                                         342552.0
# 497                                         306616.0
#
#      gfw_forest_carbon_gross_emissions_2024__Mg_CO2e
# 493                                        2915925.0
# 494                                        1827562.0
# 495                                         311241.0
# 496                                         298015.0
# 497                                         258040.0
#
# [5 rows x 32 columns]
# Data Types:
# country                                               object
# umd_tree_cover_density_2000__threshold                 int64
# umd_tree_cover_extent_2000__ha                         int64
# gfw_aboveground_carbon_stocks_2000__Mg_C               int64
# avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1      int64
# gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1        int64
# gfw_forest_carbon_gross_removals__Mg_CO2_yr-1          int64
# gfw_forest_carbon_net_flux__Mg_CO2e_yr-1               int64
# gfw_forest_carbon_gross_emissions_2001__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2002__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2003__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2004__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2005__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2006__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2007__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2008__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2009__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2010__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2011__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2012__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2013__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2014__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2015__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2016__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2017__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2018__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2019__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2020__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2021__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2022__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2023__Mg_CO2e      float64
# gfw_forest_carbon_gross_emissions_2024__Mg_CO2e      float64
# dtype: object
#
# Missing Values:
# country                                              0
# umd_tree_cover_density_2000__threshold               0
# umd_tree_cover_extent_2000__ha                       0
# gfw_aboveground_carbon_stocks_2000__Mg_C             0
# avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1    0
# gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1      0
# gfw_forest_carbon_gross_removals__Mg_CO2_yr-1        0
# gfw_forest_carbon_net_flux__Mg_CO2e_yr-1             0
# gfw_forest_carbon_gross_emissions_2001__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2002__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2003__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2004__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2005__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2006__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2007__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2008__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2009__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2010__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2011__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2012__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2013__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2014__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2015__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2016__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2017__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2018__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2019__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2020__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2021__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2022__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2023__Mg_CO2e      0
# gfw_forest_carbon_gross_emissions_2024__Mg_CO2e      0
# dtype: int64

# %% [markdown]
# ### 3.4 Country Drivers Data

# %%
# Load country drivers data
drivers_file = "../data/raw/global_forest_watch_data_country_drivers.csv"

df_drivers = pd.read_csv(drivers_file)
print("✓ Country Drivers Data Loaded")
print(f"Shape: {df_drivers.shape}")
print(f"\nColumns: {list(df_drivers.columns)}")
print(f"\nFirst few rows:")
display(df_drivers.head())

print(f"\nLast few rows:")
display(df_drivers.tail())

print(f"\nData Types:")
print(df_drivers.dtypes)

print(f"\nMissing Values:")
print(df_drivers.isnull().sum())
# Out:
# ✓ Country Drivers Data Loaded
# Shape: (21897, 5)
#
# Columns: ['country', 'threshold', 'driver', 'year', 'tc_loss_ha']
#
# First few rows:
#        country  threshold            driver  year  tc_loss_ha
# 0  Afghanistan         30  Hard commodities  2014         0.0
# 1  Afghanistan         30           Logging  2001         3.0
# 2  Afghanistan         30           Logging  2002        64.0
# 3  Afghanistan         30           Logging  2003        73.0
# 4  Afghanistan         30           Logging  2004       143.0
# Last few rows:
#         country  threshold    driver  year  tc_loss_ha
# 21892  Zimbabwe         30  Wildfire  2020       128.0
# 21893  Zimbabwe         30  Wildfire  2021        89.0
# 21894  Zimbabwe         30  Wildfire  2022       272.0
# 21895  Zimbabwe         30  Wildfire  2023       143.0
# 21896  Zimbabwe         30  Wildfire  2024       172.0
# Data Types:
# country        object
# threshold       int64
# driver         object
# year            int64
# tc_loss_ha    float64
# dtype: object
#
# Missing Values:
# country       0
# threshold     0
# driver        0
# year          0
# tc_loss_ha    0
# dtype: int64

# %% [markdown]
# ## 4. Data Summary Statistics

# %%
# Create a summary of all datasets
datasets = {
    'Country Tree Cover Loss': df_country_loss if 'df_country_loss' in locals() else None,
    'Country Primary Loss': df_primary_loss if 'df_primary_loss' in locals() else None,
    'Country Carbon Data': df_carbon if 'df_carbon' in locals() else None,
    'Country Drivers': df_drivers if 'df_drivers' in locals() else None
}

print("\n" + "="*80)
print("DATA SUMMARY")
print("="*80)

for name, df in datasets.items():
    if df is not None:
        print(f"\n{name}:")
        print(f"  Rows: {df.shape[0]:,}")
        print(f"  Columns: {df.shape[1]}")
        print(f"  Memory: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    else:
        print(f"\n{name}: Not loaded")


print("\n" + "="*80)
print("DATA STATISTICS")
print("="*80)

for name, df in datasets.items():
    if df is not None:
        print(f"\n{name}:")
        print(f"\n{df.describe(include='all')}")
    else:
        print(f"\n{name}: Not loaded")
# Out:
# ================================================================================
# DATA SUMMARY
# ================================================================================
#
# Country Tree Cover Loss:
#   Rows: 1,328
#   Columns: 30
#   Memory: 0.37 MB
#
# Country Primary Loss:
#   Rows: 76
#   Columns: 26
#   Memory: 0.02 MB
#
# Country Carbon Data:
#   Rows: 498
#   Columns: 32
#   Memory: 0.15 MB
#
# Country Drivers:
#   Rows: 21,897
#   Columns: 5
#   Memory: 3.11 MB
#
# ================================================================================
# DATA STATISTICS
# ================================================================================
#
# Country Tree Cover Loss:
#
#             country    threshold       area_ha  extent_2000_ha  \
# count          1328  1328.000000  1.328000e+03    1.328000e+03
# unique          166          NaN           NaN             NaN
# top     Afghanistan          NaN           NaN             NaN
# freq              8          NaN           NaN             NaN
# mean            NaN    28.125000  7.814805e+07    3.038020e+07
# std             NaN    22.499791  2.015752e+08    1.056704e+08
# min             NaN     0.000000  2.094000e+03    0.000000e+00
# 25%             NaN    13.750000  5.117777e+06    5.480255e+05
# 50%             NaN    22.500000  2.022587e+07    3.622986e+06
# 75%             NaN    35.000000  6.201997e+07    1.831977e+07
# max             NaN    75.000000  1.689455e+09    1.689455e+09
#
#         extent_2010_ha  gain_2000-2012_ha  tc_loss_ha_2001  tc_loss_ha_2002  \
# count     1.328000e+03       1.328000e+03     1.328000e+03     1.328000e+03
# unique             NaN                NaN              NaN              NaN
# top                NaN                NaN              NaN              NaN
# freq               NaN                NaN              NaN              NaN
# mean      2.994347e+07       7.867308e+05     7.906576e+04     9.644243e+04
# std       1.047382e+08       3.417373e+06     3.124548e+05     4.116669e+05
# min       0.000000e+00       0.000000e+00     0.000000e+00     0.000000e+00
# 25%       5.412700e+05       1.383200e+04     5.145000e+02     3.932500e+02
# 50%       3.499126e+06       9.435900e+04     6.940500e+03     5.172000e+03
# 75%       1.819886e+07       3.882400e+05     3.154525e+04     3.242225e+04
# max       1.689455e+09       3.722054e+07     2.933201e+06     3.715945e+06
#
#         tc_loss_ha_2003  tc_loss_ha_2004  ...  tc_loss_ha_2015  \
# count      1.328000e+03     1.328000e+03  ...     1.328000e+03
# unique              NaN              NaN  ...              NaN
# top                 NaN              NaN  ...              NaN
# freq                NaN              NaN  ...              NaN
# mean       8.478851e+04     1.162822e+05  ...     1.153580e+05
# std        3.768918e+05     4.947177e+05  ...     3.906740e+05
# min        0.000000e+00     0.000000e+00  ...     0.000000e+00
# 25%        3.120000e+02     5.327500e+02  ...     3.230000e+02
# 50%        3.940500e+03     6.147500e+03  ...     7.497500e+03
# 75%        2.848925e+04     3.860275e+04  ...     5.140025e+04
# max        3.489258e+06     4.133606e+06  ...     2.925679e+06
#
#         tc_loss_ha_2016  tc_loss_ha_2017  tc_loss_ha_2018  tc_loss_ha_2019  \
# count      1.328000e+03     1.328000e+03     1.328000e+03     1.328000e+03
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean       1.756815e+05     1.745346e+05     1.469773e+05     1.438572e+05
# std        6.453353e+05     6.079198e+05     5.459009e+05     4.588106e+05
# min        0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%        6.187500e+02     7.272500e+02     5.825000e+02     5.377500e+02
# 50%        1.421250e+04     1.631400e+04     1.156500e+04     1.108200e+04
# 75%        1.063302e+05     9.793725e+04     7.669250e+04     7.689425e+04
# max        6.407238e+06     6.143920e+06     6.621833e+06     4.847068e+06
#
#         tc_loss_ha_2020  tc_loss_ha_2021  tc_loss_ha_2022  tc_loss_ha_2023  \
# count      1.328000e+03     1.328000e+03     1.328000e+03     1.328000e+03
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean       1.553305e+05     1.498121e+05     1.356731e+05     1.686809e+05
# std        5.799769e+05     6.139020e+05     4.909377e+05     7.502341e+05
# min        0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%        6.575000e+02     5.275000e+02     3.860000e+02     8.287500e+02
# 50%        1.195450e+04     9.935000e+03     9.190500e+03     1.396300e+04
# 75%        8.074400e+04     7.072375e+04     6.527200e+04     7.677800e+04
# max        8.217252e+06     8.559449e+06     5.126743e+06     1.017602e+07
#
#         tc_loss_ha_2024
# count      1.328000e+03
# unique              NaN
# top                 NaN
# freq                NaN
# mean       1.776107e+05
# std        6.924869e+05
# min        0.000000e+00
# 25%        6.737500e+02
# 50%        1.095100e+04
# 75%        8.178400e+04
# max        7.421840e+06
#
# [11 rows x 30 columns]
#
# Country Primary Loss:
#
#        country  threshold      area__ha  tc_loss_ha_2002  tc_loss_ha_2003  \
# count       76       76.0  7.600000e+01     7.600000e+01     7.600000e+01
# unique      76        NaN           NaN              NaN              NaN
# top     Angola        NaN           NaN              NaN              NaN
# freq         1        NaN           NaN              NaN              NaN
# mean       NaN       30.0  1.349796e+07     3.500986e+04     3.268253e+04
# std        NaN        0.0  4.300172e+07     1.883565e+05     1.816783e+05
# min        NaN       30.0  1.653000e+03     0.000000e+00     0.000000e+00
# 25%        NaN       30.0  2.271512e+05     1.325000e+02     1.225000e+02
# 50%        NaN       30.0  1.833100e+06     2.029500e+03     1.582500e+03
# 75%        NaN       30.0  7.487047e+06     1.013250e+04     1.014375e+04
# max        NaN       30.0  3.432610e+08     1.621738e+06     1.570540e+06
#
#         tc_loss_ha_2004  tc_loss_ha_2005  tc_loss_ha_2006  tc_loss_ha_2007  \
# count      7.600000e+01     7.600000e+01     7.600000e+01     7.600000e+01
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean       4.462941e+04     4.370550e+04     3.695367e+04     3.814787e+04
# std        2.367232e+05     2.157229e+05     1.706006e+05     1.452392e+05
# min        0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%        2.035000e+02     2.170000e+02     2.455000e+02     1.845000e+02
# 50%        2.277000e+03     2.320000e+03     2.528500e+03     3.063500e+03
# 75%        1.197275e+04     1.202100e+04     1.418450e+04     1.843200e+04
# max        2.016350e+06     1.824217e+06     1.415536e+06     1.149515e+06
#
#         tc_loss_ha_2008  ...  tc_loss_ha_2015  tc_loss_ha_2016  \
# count      7.600000e+01  ...        76.000000     7.600000e+01
# unique              NaN  ...              NaN              NaN
# top                 NaN  ...              NaN              NaN
# freq                NaN  ...              NaN              NaN
# mean       3.563292e+04  ...     38528.013158     8.050946e+04
# std        1.354756e+05  ...    126231.483498     3.430140e+05
# min        0.000000e+00  ...         0.000000     0.000000e+00
# 25%        2.227500e+02  ...       253.750000     5.015000e+02
# 50%        3.677500e+03  ...      3392.500000     4.904000e+03
# 75%        1.528925e+04  ...     16938.250000     4.590225e+04
# max        1.075087e+06  ...    828839.000000     2.830943e+06
#
#         tc_loss_ha_2017  tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  \
# count      7.600000e+01     7.600000e+01     7.600000e+01     7.600000e+01
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean       6.532487e+04     4.792633e+04     4.931018e+04     5.531720e+04
# std        2.536957e+05     1.680912e+05     1.702689e+05     2.058852e+05
# min        0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%        5.145000e+02     3.417500e+02     3.247500e+02     3.065000e+02
# 50%        7.123000e+03     4.061500e+03     5.047500e+03     4.094000e+03
# 75%        3.110525e+04     2.709850e+04     3.070975e+04     3.433400e+04
# max        2.134474e+06     1.347176e+06     1.361053e+06     1.703491e+06
#
#         tc_loss_ha_2021  tc_loss_ha_2022  tc_loss_ha_2023  tc_loss_ha_2024
# count      7.600000e+01     7.600000e+01     7.600000e+01     7.600000e+01
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean       4.926511e+04     5.407901e+04     4.911196e+04     8.849616e+04
# std        1.885591e+05     2.149624e+05     1.549588e+05     3.671704e+05
# min        0.000000e+00     0.000000e+00     0.000000e+00     0.000000e+00
# 25%        3.012500e+02     2.927500e+02     2.740000e+02     3.660000e+02
# 50%        4.050000e+03     3.952000e+03     4.538500e+03     4.598000e+03
# 75%        2.444950e+04     2.350000e+04     2.459825e+04     4.037175e+04
# max        1.546964e+06     1.772214e+06     1.136250e+06     2.823646e+06
#
# [11 rows x 26 columns]
#
# Country Carbon Data:
#
#             country  umd_tree_cover_density_2000__threshold  \
# count           498                              498.000000
# unique          166                                     NaN
# top     Afghanistan                                     NaN
# freq              3                                     NaN
# mean            NaN                               51.666667
# std             NaN                               18.427446
# min             NaN                               30.000000
# 25%             NaN                               30.000000
# 50%             NaN                               50.000000
# 75%             NaN                               75.000000
# max             NaN                               75.000000
#
#         umd_tree_cover_extent_2000__ha  \
# count                     4.980000e+02
# unique                             NaN
# top                                NaN
# freq                               NaN
# mean                      1.931269e+07
# std                       6.887766e+07
# min                       0.000000e+00
# 25%                       1.426352e+05
# 50%                       2.085216e+06
# 75%                       9.780736e+06
# max                       7.612265e+08
#
#         gfw_aboveground_carbon_stocks_2000__Mg_C  \
# count                               4.980000e+02
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                                1.587066e+09
# std                                 5.357827e+09
# min                                 0.000000e+00
# 25%                                 9.929742e+06
# 50%                                 1.562127e+08
# 75%                                 6.875177e+08
# max                                 5.556887e+10
#
#         avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1  \
# count                                          498.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           336.757028
# std                                            178.168604
# min                                              0.000000
# 25%                                            210.000000
# 50%                                            320.000000
# 75%                                            465.500000
# max                                            770.000000
#
#         gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       4.839584e+07
# std                                        1.696282e+08
# min                                        0.000000e+00
# 25%                                        1.937462e+05
# 50%                                        3.567744e+06
# 75%                                        2.802821e+07
# max                                        1.589982e+09
#
#         gfw_forest_carbon_gross_removals__Mg_CO2_yr-1  \
# count                                    4.980000e+02
# unique                                            NaN
# top                                               NaN
# freq                                              NaN
# mean                                     7.027193e+07
# std                                      2.189253e+08
# min                                      0.000000e+00
# 25%                                      1.035810e+06
# 50%                                      1.179340e+07
# 75%                                      4.982675e+07
# max                                      1.998131e+09
#
#         gfw_forest_carbon_net_flux__Mg_CO2e_yr-1  \
# count                               4.980000e+02
# unique                                       NaN
# top                                          NaN
# freq                                         NaN
# mean                               -2.187608e+07
# std                                 1.044479e+08
# min                                -1.373904e+09
# 25%                                -1.961919e+07
# 50%                                -3.203280e+06
# 75%                                -5.210875e+04
# max                                 3.995718e+08
#
#         gfw_forest_carbon_gross_emissions_2001__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       2.762562e+07
# std                                        1.143494e+08
# min                                        0.000000e+00
# 25%                                        1.226555e+05
# 50%                                        2.095027e+06
# 75%                                        1.264239e+07
# max                                        1.221139e+09
#
#         gfw_forest_carbon_gross_emissions_2002__Mg_CO2e  ...  \
# count                                      4.980000e+02  ...
# unique                                              NaN  ...
# top                                                 NaN  ...
# freq                                                NaN  ...
# mean                                       3.408261e+07  ...
# std                                        1.531540e+08  ...
# min                                        0.000000e+00  ...
# 25%                                        9.376250e+04  ...
# 50%                                        1.902934e+06  ...
# 75%                                        1.246289e+07  ...
# max                                        1.655445e+09  ...
#
#         gfw_forest_carbon_gross_emissions_2015__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       4.691583e+07
# std                                        1.655795e+08
# min                                        0.000000e+00
# 25%                                        6.117025e+04
# 50%                                        2.512829e+06
# 75%                                        1.951526e+07
# max                                        1.269603e+09
#
#         gfw_forest_carbon_gross_emissions_2016__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       7.054879e+07
# std                                        2.621819e+08
# min                                        0.000000e+00
# 25%                                        1.722650e+05
# 50%                                        4.575936e+06
# 75%                                        3.721551e+07
# max                                        2.631722e+09
#
#         gfw_forest_carbon_gross_emissions_2017__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       6.639299e+07
# std                                        2.241920e+08
# min                                        0.000000e+00
# 25%                                        1.516740e+05
# 50%                                        5.839588e+06
# 75%                                        3.841608e+07
# max                                        2.334531e+09
#
#         gfw_forest_carbon_gross_emissions_2018__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       5.620084e+07
# std                                        1.868647e+08
# min                                        0.000000e+00
# 25%                                        1.257438e+05
# 50%                                        4.530992e+06
# 75%                                        3.228359e+07
# max                                        1.718707e+09
#
#         gfw_forest_carbon_gross_emissions_2019__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       5.321485e+07
# std                                        1.667246e+08
# min                                        0.000000e+00
# 25%                                        8.395750e+04
# 50%                                        3.387612e+06
# 75%                                        3.243832e+07
# max                                        1.532889e+09
#
#         gfw_forest_carbon_gross_emissions_2020__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       5.388459e+07
# std                                        1.700612e+08
# min                                        0.000000e+00
# 25%                                        1.501205e+05
# 50%                                        3.406693e+06
# 75%                                        3.563274e+07
# max                                        1.680954e+09
#
#         gfw_forest_carbon_gross_emissions_2021__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       5.474384e+07
# std                                        1.861965e+08
# min                                        0.000000e+00
# 25%                                        1.711392e+05
# 50%                                        4.448366e+06
# 75%                                        3.276482e+07
# max                                        1.868491e+09
#
#         gfw_forest_carbon_gross_emissions_2022__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       5.384661e+07
# std                                        1.916172e+08
# min                                        0.000000e+00
# 25%                                        1.304668e+05
# 50%                                        3.514034e+06
# 75%                                        3.106682e+07
# max                                        2.082946e+09
#
#         gfw_forest_carbon_gross_emissions_2023__Mg_CO2e  \
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       6.605417e+07
# std                                        2.737506e+08
# min                                        0.000000e+00
# 25%                                        2.771108e+05
# 50%                                        5.197532e+06
# 75%                                        3.512411e+07
# max                                        3.791767e+09
#
#         gfw_forest_carbon_gross_emissions_2024__Mg_CO2e
# count                                      4.980000e+02
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                       6.450019e+07
# std                                        2.351036e+08
# min                                        0.000000e+00
# 25%                                        2.127560e+05
# 50%                                        4.353297e+06
# 75%                                        3.573186e+07
# max                                        2.396129e+09
#
# [11 rows x 32 columns]
#
# Country Drivers:
#
#        country  threshold                 driver          year    tc_loss_ha
# count    21897    21897.0                  21897  21897.000000  2.189700e+04
# unique     158        NaN                      7           NaN           NaN
# top       Laos        NaN  Permanent agriculture           NaN           NaN
# freq       168        NaN                   3576           NaN           NaN
# mean       NaN       30.0                    NaN   2012.406448  2.351340e+04
# std        NaN        0.0                    NaN      6.930328  1.698828e+05
# min        NaN       30.0                    NaN   2001.000000  0.000000e+00
# 25%        NaN       30.0                    NaN   2006.000000  2.600000e+01
# 50%        NaN       30.0                    NaN   2012.000000  2.360000e+02
# 75%        NaN       30.0                    NaN   2018.000000  2.375000e+03
# max        NaN       30.0                    NaN   2024.000000  7.789588e+06

# %% [markdown]
# ## 5. Quick Data Quality Check

# %%
def data_quality_check(df, dataset_name):
    """Perform basic data quality checks"""
    print(f"\n{'='*60}")
    print(f"Data Quality Check: {dataset_name}")
    print(f"{'='*60}")
    
    # Missing values
    missing = df.isnull().sum()
    if missing.sum() > 0:
        print(f"\n⚠ Missing Values:")
        print(missing[missing > 0])
    else:
        print("\n✓ No missing values")
    
    # Duplicate rows
    duplicates = df.duplicated().sum()
    if duplicates > 0:
        print(f"\n⚠ Duplicate rows: {duplicates}")
    else:
        print("✓ No duplicate rows")
    
    # Data types
    print(f"\nData Types:")
    print(df.dtypes.value_counts())
    
    return True

# Run quality checks on loaded datasets
for name, df in datasets.items():
    if df is not None:
        data_quality_check(df, name)
# Out:
# ============================================================
# Data Quality Check: Country Tree Cover Loss
# ============================================================
#
# ✓ No missing values
# ✓ No duplicate rows
#
# Data Types:
# int64     29
# object     1
# Name: count, dtype: int64
#
# ============================================================
# Data Quality Check: Country Primary Loss
# ============================================================
#
# ✓ No missing values
# ✓ No duplicate rows
#
# Data Types:
# int64     25
# object     1
# Name: count, dtype: int64
#
# ============================================================
# Data Quality Check: Country Carbon Data
# ============================================================
#
# ✓ No missing values
# ✓ No duplicate rows
#
# Data Types:
# float64    24
# int64       7
# object      1
# Name: count, dtype: int64
#
# ============================================================
# Data Quality Check: Country Drivers
# ============================================================
#
# ✓ No missing values
# ✓ No duplicate rows
#
# Data Types:
# object     2
# int64      2
# float64    1
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Save Data Inventory
#
# Create a metadata file documenting all downloaded data

# %%
import json
from datetime import datetime

# Create data inventory
inventory = {
    'created_at': datetime.now().isoformat(),
    'data_source': 'Global Forest Watch',
    'data_url': 'https://www.globalforestwatch.org/',
    'time_period': '2001-2024',
    'datasets': {}
}

for name, df in datasets.items():
    if df is not None:
        inventory['datasets'][name] = {
            'rows': int(df.shape[0]),
            'columns': int(df.shape[1]),
            'column_names': list(df.columns),
            'memory_mb': float(df.memory_usage(deep=True).sum() / 1024**2)
        }

# Save inventory
inventory_file = "../data/data_inventory.json"
with open(inventory_file, 'w') as f:
    json.dump(inventory, f, indent=2)

print(f"✓ Data inventory saved to: {inventory_file}")
print(f"\nInventory:")
print(json.dumps(inventory, indent=2))
# Out:
# ✓ Data inventory saved to: ../data/data_inventory.json
#
# Inventory:
# {
#   "created_at": "2025-10-22T20:52:05.891608",
#   "data_source": "Global Forest Watch",
#   "data_url": "https://www.globalforestwatch.org/",
#   "time_period": "2001-2024",
#   "datasets": {
#     "Country Tree Cover Loss": {
#       "rows": 1328,
#       "columns": 30,
#       "column_names": [
#         "country",
#         "threshold",
#         "area_ha",
#         "extent_2000_ha",
#         "extent_2010_ha",
#         "gain_2000-2012_ha",
#         "tc_loss_ha_2001",
#         "tc_loss_ha_2002",
#         "tc_loss_ha_2003",
#         "tc_loss_ha_2004",
#         "tc_loss_ha_2005",
#         "tc_loss_ha_2006",
#         "tc_loss_ha_2007",
#         "tc_loss_ha_2008",
#         "tc_loss_ha_2009",
#         "tc_loss_ha_2010",
#         "tc_loss_ha_2011",
#         "tc_loss_ha_2012",
#         "tc_loss_ha_2013",
#         "tc_loss_ha_2014",
#         "tc_loss_ha_2015",
#         "tc_loss_ha_2016",
#         "tc_loss_ha_2017",
#         "tc_loss_ha_2018",
#         "tc_loss_ha_2019",
#         "tc_loss_ha_2020",
#         "tc_loss_ha_2021",
#         "tc_loss_ha_2022",
#         "tc_loss_ha_2023",
#         "tc_loss_ha_2024"
#       ],
#       "memory_mb": 0.3681602478027344
#     },
#     "Country Primary Loss": {
#       "rows": 76,
#       "columns": 26,
#       "column_names": [
#         "country",
#         "threshold",
#         "area__ha",
#         "tc_loss_ha_2002",
#         "tc_loss_ha_2003",
#         "tc_loss_ha_2004",
#         "tc_loss_ha_2005",
#         "tc_loss_ha_2006",
#         "tc_loss_ha_2007",
#         "tc_loss_ha_2008",
#         "tc_loss_ha_2009",
#         "tc_loss_ha_2010",
#         "tc_loss_ha_2011",
#         "tc_loss_ha_2012",
#         "tc_loss_ha_2013",
#         "tc_loss_ha_2014",
#         "tc_loss_ha_2015",
#         "tc_loss_ha_2016",
#         "tc_loss_ha_2017",
#         "tc_loss_ha_2018",
#         "tc_loss_ha_2019",
#         "tc_loss_ha_2020",
#         "tc_loss_ha_2021",
#         "tc_loss_ha_2022",
#         "tc_loss_ha_2023",
#         "tc_loss_ha_2024"
#       ],
#       "memory_mb": 0.01887798309326172
#     },
#     "Country Carbon Data": {
#       "rows": 498,
#       "columns": 32,
#       "column_names": [
#         "country",
#         "umd_tree_cover_density_2000__threshold",
#         "umd_tree_cover_extent_2000__ha",
#         "gfw_aboveground_carbon_stocks_2000__Mg_C",
#         "avg_gfw_aboveground_carbon_stocks_2000__Mg_C_ha-1",
#         "gfw_forest_carbon_gross_emissions__Mg_CO2e_yr-1",
#         "gfw_forest_carbon_gross_removals__Mg_CO2_yr-1",
#         "gfw_forest_carbon_net_flux__Mg_CO2e_yr-1",
#         "gfw_forest_carbon_gross_emissions_2001__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2002__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2003__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2004__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2005__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2006__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2007__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2008__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2009__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2010__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2011__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2012__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2013__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2014__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2015__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2016__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2017__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2018__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2019__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2020__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2021__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2022__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2023__Mg_CO2e",
#         "gfw_forest_carbon_gross_emissions_2024__Mg_CO2e"
#       ],
#       "memory_mb": 0.14574337005615234
#     },
#     "Country Drivers": {
#       "rows": 21897,
#       "columns": 5,
#       "column_names": [
#         "country",
#         "threshold",
#         "driver",
#         "year",
#         "tc_loss_ha"
#       ],
#       "memory_mb": 3.1143760681152344
#     }
#   }
# }
